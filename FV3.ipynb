# %%
#conda install -c conda-forge geopandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Traceback (most recent call last):
#   File "C:\Users\wtick\anaconda\Scripts\conda-script.py", line 11, in <module>
#     from conda.cli import main
# ModuleNotFoundError: No module named 'conda'

# %%
#conda install graphpca

# %%
#conda install matplotlib

# %%
import numpy as np
import math
import networkx as nx
from scipy.stats import truncnorm
import scipy.io
from scipy import sparse
import matplotlib.pyplot as plt
from shapely.geometry import *
import geopandas as gpd
import pandas as pd

# %%
import scipy.io

# %%
import setuptools
import math
import numpy as np
import networkx as nx
from networkx.utils import powerlaw_sequence
from scipy import sparse, io 
from scipy.stats import truncnorm
import matplotlib.pyplot as plt
from shapely.geometry import *
import geopandas as gpd
import pandas as pd
from sklearn.preprocessing import normalize

import numpy as np

# %%
mat = scipy.io.loadmat('fungal_networks/Pi_M_I_U_N_46d_1.mat')

# %%
mat

# %%
[(x[0],x[1]) for x in mat['coordinates']]

# %%
s2 = gpd.GeoSeries([Point(x) for x in mat2['coordinates']])
s2.plot(markersize=0.2, figsize=(10,15))

# %%
mtx = sparse.csc_matrix(mat['A'])
mtx.todense()

# %%
#A = mat['coordinates'].todense()  # that's just how the file came
G = nx.from_numpy_matrix(sparse.csc_matrix(mat['A']).todense(), parallel_edges = False)
nx.draw(G, mat['coordinates'], node_size = 0.2)

# %%
#A = mat['coordinates'].todense()  # that's just how the file came
G3 = nx.from_numpy_matrix(sparse.csc_matrix(mat2['A']).todense(), parallel_edges = False)
nx.draw(G3, mat2['coordinates'], node_size = 0.2)

# %%
G.edges(0, data = True)

# %%
mat2

# %%
nx.set_node_attributes(G2, pos2, 'coord')
G2.nodes( data=True)

# %%
EdgeWeights
# Out:
# array([0.3789521794033918, 0.0404715082636455, 0.010499900377076668,
#        0.003858679354887701, 0.12269861603902259, 0.13791079515035695,
#        0.012833871450147262, 0.0037494463408106996, 0.3646662700713439,
#        0.02538415469586122, 0.024697730988999418, 0.0076565248376884824,
#        0.0004886326289688924, 0.07495177813320536, 0.02827266933836536,
#        0.0045716162358466145, 0.016021502092628856, 0.010754736502413114,
#        array([0.01288966]), array([0.00938164]), array([0.00475267]),
#        array([0.00169185]), array([0.01380008]), array([0.00793222]),
#        array([0.00253494]), array([0.00469527]), array([0.00010798]),
#        array([0.02730375]), array([0.01210887]), array([0.00570535]),
#        array([0.00093104]), array([0.03175562]), array([0.00737798]),
#        array([0.00136726]), array([0.00237149]), array([0.00227494])],
#       dtype=object)

# %%
Gsim.edges(data = True)
# Out:
# EdgeDataView([(0, 2, {'weight': 0.3789521794033918, 'length': 1.8749874961567734, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 2.612291625584219, '': 0}), (0, 3, {'weight': 0.0404715082636455, 'length': 3.00701302583081, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 3.253479600062826, '': 0}), (0, 4, {'weight': 0.010499900377076668, 'length': 1.98070943851141, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.5096709341894856, '': 0}), (0, 5, {'weight': 0.003858679354887701, 'length': 2.8134194462351805, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.6245578401634693, '': 0}), (0, 11, {'weight': 0.12269861603902259, 'length': 1.6547725442938566, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 4.279605651385327}), (0, 12, {'weight': 0.13791079515035695, 'length': 0.5890045950810177, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 1.3892184832189167}), (0, 13, {'weight': 0.012833871450147262, 'length': 2.6928053630649282, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.92970600036908}), (0, 14, {'weight': 0.0037494463408106996, 'length': 2.7446735423743296, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.4014698650266762}), (1, 6, {'weight': 0.3646662700713439, 'length': 1.6889093521576035, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 2.9135847062032774, '': 0}), (1, 7, {'weight': 0.02538415469586122, 'length': 2.4736614239894434, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 2.2030017509857456, '': 0}), (1, 8, {'weight': 0.024697730988999418, 'length': 1.443563067329953, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.8116245097109336, '': 0}), (1, 9, {'weight': 0.0076565248376884824, 'length': 3.0981282336795153, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.9574996636679675, '': 0}), (1, 10, {'weight': 0.0004886326289688924, 'length': 2.6043025166670746, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.11428936943207602, '': 0}), (1, 15, {'weight': 0.07495177813320536, 'length': 2.257188546785618, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 3.532758281712116}), (1, 16, {'weight': 0.02827266933836536, 'length': 2.7836874061007055, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 1.922605775899251}), (1, 17, {'weight': 0.0045716162358466145, 'length': 2.936474284686405, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.5911599517183086}), (1, 18, {'weight': 0.016021502092628856, 'length': 1.1903271975732292, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.4735376645312839}), (1, 19, {'weight': 0.010754736502413114, 'length': 1.784735234572366, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.4799383261390404}), (2, 20, {'weight': array([0.01288966]), 'length': 2.1150415007454715, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': array([0.02726217])}), (3, 21, {'weight': array([0.00938164]), 'length': 2.1066035802275676, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': array([0.01976339])}), (4, 22, {'weight': array([0.00475267]), 'length': 1.0530948006596683, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': array([0.00500501])}), (5, 23, {'weight': array([0.00169185]), 'length': 1.5350605825817407, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': array([0.0025971])}), (6, 28, {'weight': array([0.01380008]), 'length': 1.8272365064176388, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': array([0.02521601])}), (7, 29, {'weight': array([0.00793222]), 'length': 1.8689417702770514, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': array([0.01482486])}), (8, 33, {'weight': array([0.00253494]), 'length': 2.2195213592740246, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': a ...

# %%
EdgeWeights = np.array([x[2] for x in list(Gsim.edges(data = 'weight'))])
StandardEdgeWeights = (EdgeWeights - np.mean(EdgeWeights)) / np.std(EdgeWeights)
StandardEdgeWeights
# Out:
# <ipython-input-147-3d1b17792699>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   EdgeWeights = np.array([x[2] for x in list(Gsim.edges(data = 'weight'))])
# array([3.939548248001302, 0.012745619449848391, -0.3349628279323686,
#        -0.41200936674626687, 0.9666837626923768, 1.1431642238047952,
#        -0.307885820214806, -0.41327660745858824, 3.773813684407351,
#        -0.16228670794529654, -0.17025008856413282, -0.3679495698471488,
#        -0.4511061585870499, 0.412760231513326, -0.1287762955114011,
#        -0.4037383998732873, -0.27090528497892546, -0.33200640751565336,
#        array([-0.3072386]), array([-0.34793607]), array([-0.40163795]),
#        array([-0.43714728]), array([-0.29667656]), array([-0.36475116]),
#        array([-0.42736642]), array([-0.40230387]), array([-0.4555222]),
#        array([-0.140017]), array([-0.31629671]), array([-0.39058566]),
#        array([-0.44597362]), array([-0.08836969]), array([-0.37118105]),
#        array([-0.44091303]), array([-0.42926269]), array([-0.43038268])],
#       dtype=object)

# %%
  #normalize edge weights for viweing with networkx graph
def standardWidth(G):
    EdgeWeights = [x[2] for x in list(G.edges(data = 'weight'))]
    StandardEdgeWeights = (EdgeWeights - np.mean(EdgeWeights)) / np.std(EdgeWeights)
    return StandardEdgeWeights

# %%
#view Empirical networks
def drawMatNetworks( filename):
    print("fungal network:", filename)
    matC = scipy.io.loadmat('fungal_MATLAB\Conductance' +filename)
    positionsC = dict()
    for i in range(len(matC['coordinates'])):
        positionsC[i] = (matC['coordinates'][i][0],matC['coordinates'][i][1])
    GC = nx.from_numpy_matrix(sparse.csc_matrix(matC['A']).todense(), parallel_edges = False)
    nx.set_node_attributes(GC, positionsC, 'coord')
    posC = matC['coordinates']
    #normalize edge weights for viweing
    StandardEdgeWeightsC = standardWidth(GC) + 0.5
    print("Conductance")
    nx.draw(GC, pos =posC, width = StandardEdgeWeightsC, node_size = 0.2)
    plt.show()

    matP = scipy.io.loadmat('fungal_MATLAB\PathScore' +filename )
    positionsP = dict()
    for i in range(len(matP['coordinates'])):
        positionsP[i] = (matP['coordinates'][i][0],matP['coordinates'][i][1])
    GP = nx.from_numpy_matrix(sparse.csc_matrix(matP['A']).todense(), parallel_edges = False)
    nx.set_node_attributes(GP, positionsP, 'coord')
    posP = matP['coordinates']
    #normalize edge weights for viweing
    StandardEdgeWeightsP = standardWidth(GP) + 0.5
    print("Path Score:", )
    nx.draw(GP, pos =posP, width= StandardEdgeWeightsP, node_size = 0.2)
    plt.show()

# %%
drawMatNetworks('\Pv_M_I+4R_U_N_19d_2')
drawMatNetworks('\Pv_M_I+4R_U_N_32d_2')
drawMatNetworks('\Pv_M_I+4R_U_N_50d_2')

drawMatNetworks('\Pv_M_5xI_U_N_18d_1')
drawMatNetworks('\Pv_M_5xI_U_N_25d_1')
drawMatNetworks('\Pv_M_5xI_U_N_35d_1')
# Out:
# fungal network: \Pv_M_I+4R_U_N_19d_2
# Conductance
# Path Score:
# fungal network: \Pv_M_I+4R_U_N_32d_2
# Conductance
# Path Score:
# fungal network: \Pv_M_I+4R_U_N_50d_2
# Conductance
# Path Score:
# fungal network: \Pv_M_5xI_U_N_18d_1
# Conductance
# Path Score:
# fungal network: \Pv_M_5xI_U_N_25d_1
# Conductance
# Path Score:
# fungal network: \Pv_M_5xI_U_N_35d_1
# Conductance
# Path Score:

# %%
drawMatNetworks('\Pp_M_Tokyo_U_N_26h_4')
# Out:
# fungal network: \Pp_M_Tokyo_U_N_26h_4
# Conductance
# Path Score:

# %%
filename ='\Pv_M_I+4R_U_N_50d_2'
print("fungal network:", filename)
matC = scipy.io.loadmat('fungal_MATLAB\Conductance' +filename)
positionsC = dict()
for i in range(len(matC['coordinates'])):
    positionsC[i] = (matC['coordinates'][i][0],matC['coordinates'][i][1])
GC = nx.from_numpy_matrix(sparse.csc_matrix(matC['A']).todense(), parallel_edges = False)
nx.set_node_attributes(GC, positionsC, 'coord')
posC = matC['coordinates']
#normalize edge weights for viweing
EdgeWeightsC = np.array([x[2] for x in list(GC.edges(data = 'weight'))])
StandardEdgeWeightsC = (EdgeWeightsC - np.mean(EdgeWeightsC)) / np.std(EdgeWeightsC)
StandardEdgeWeightsC +=1
print("Conductance")
nx.draw(GC, pos =posC, width = StandardEdgeWeightsC, node_size = 0.2)
plt.show()
# Out:
# fungal network: \Pv_M_I+4R_U_N_50d_2
# Conductance

# %%
#set food sources map
f1 = Polygon([(-1,-1),(-1,1),(1,1),(1,-1)])
f2 = Polygon([(5,5),(5,6),(6,5)])
foodMap = MultiPolygon([f1,f2])

# %%
#foodMap is a MultiPolygon shapely type object
#coordinate is (x,y) tuple
#returns boolean
def hasFood(coordinate, foodMap):
    return foodMap.intersects(Point(coordinate))

# %%
def ranged_normal(mean, sd, low, upp):
    return truncnorm(
        (low - mean) / sd, (upp - mean) / sd, loc=mean, scale=sd).rvs(1)

# %%
def edgeLength(coord1, coord2)->float:
    return math.sqrt((coord1[0]-coord2[0])**2 + (coord1[1]-coord2[1])**2)

# %%
#coordinate = tuple, food = num
#returns new node coordinates, weight, length, food used
def hyphalGrowth(coordinates,food):
    if(food < 0.4):
        MaxL = 2
    else:
        MaxL = food#adjust value for maximum length relative to food
    x = coordinates[0]
    y = coordinates[1]
    #creates bimodal distribution \/
    xn = x + (np.random.choice([-1,1], size = 1)*ranged_normal(1, 0.7, 0.2, MaxL))[0]#ajust values for mean hyphal growth length
    yn = y + (np.random.choice([-1,1], size = 1)*ranged_normal(1, 0.7, 0.2, MaxL))[0]
    coord2 = (xn,yn)
    Elength = edgeLength(coordinates, coord2)
    assert(Elength != 0)
    MaxW = food/Elength
    if(MaxW <= 0.3):#prevents infinite edges added
        weight = MaxW
    else:
        weight = ranged_normal(MaxW/2, 0.3, 0.1, MaxW)[0]#min val=> still okay to add small edges
    foodN = food - (Elength*weight)
    return (coord2, weight, Elength, foodN)

# %%
def porpEdgeGrowth(G, edgeNum,  food, edgeWSum):
    if( food < 0.2):
        G.edges[edgeNum]['weight'] = float((food/ G.edges[edgeNum]['length']) + G.edges[edgeNum]['weight'])
        return 0
    else:
        MaxW = (food/G.edges[edgeNum]['length'])
        p = (G.edges[edgeNum]['weight']/edgeWSum)* MaxW
        Wadd = ranged_normal(p-0.01, 0.2, 0.001, MaxW)[0]
        G.edges[edgeNum]['weight'] = Wadd +G.edges[edgeNum]['weight']
        return food - Wadd*G.edges[edgeNum]['length']

# %%
Gsim.edges(0, data = 'weight')
# Out:
# EdgeDataView([(0, 2, 1587.0072123377831), (0, 3, 461.03308353483595), (0, 4, 53.059013483421), (0, 1238, 1.4271401376524762), (0, 3043, 1.560016206831545), (0, 3261, 1.3751420155559362), (0, 3270, 2.316502826195797), (0, 3761, 43.739898060803185), (0, 3763, 22.145204821963876), (0, 3765, 2.776981230632976), (0, 3771, 23.02149511325373), (0, 3773, 12.318241085799055), (0, 3775, 4.407724303483174), (0, 3780, 3.1966298195179994), (0, 3787, 2.839134062353317), (0, 3794, 1.0240069550144082), (0, 3796, 1.0491568504048292)])

# %%
#given a graph and a specific edge number returns availabel food resources to be transfered. 
#transfer amount is porportional to the current edge weight divided by sum of neighbor edge weights 
def ResourceTransferAmount(G, Edge):
    Available = G.edges[Edge]['weight'] * G.edges[Edge]['length']
    #plasticity = abs((1/G.edges[Edge]['Rigidness']))
    SumNeighborWeights = sum([x[2] for x in list(G.edges(Edge[0], data = 'weight'))]) + sum([x[2] for x in list(G.edges(Edge[1], data = 'weight'))]) - G.edges[Edge]['weight'] 
    transfer =(Available*(G.edges[Edge]['weight']/SumNeighborWeights))
    transfer
    G.edges[Edge]['weight'] = (transfer/G.edges[Edge]['length'])
    return Available #units are Weight x Length

# %%
#Resolves all spatial intersections of edges in graph GS and returns new graph
#splits edge and distributes edge attributes, new edge is added to graph and old edges are removed
def ResolveIntersections(GS, nodeNum):
    
    GLines = []
    invertNodesDict = {v: k for k, v in dict(GS.nodes(data = 'coord')).items()}
    invertEdgeDict = {v: k for k, v in dict(GS.nodes(data = 'coord')).items()}
    #convert current graph to shapely edge lines
    GCoordList = list(dict(GS.nodes(data = 'coord')).values())
    for i  in GS.edges():
        GLines.append(LineString([(nx.get_node_attributes(GS, 'coord')[i[0]][0],nx.get_node_attributes(GS, 'coord')[i[0]][1]), (nx.get_node_attributes(GS, 'coord')[i[1]][0],nx.get_node_attributes(GS, 'coord')[i[1]][1])  ]))

    IntersectLines = MultiLineString(GLines)
    for line in IntersectLines:
        IntersectionsMP = []
        #find intersections of each individual line
        NLines = gpd.GeoSeries(MultiLineString([i for i in GLines if i != line]))
        IntersectionsMP = NLines.unary_union.intersection(line)
        if(IntersectionsMP.is_empty):
            pass

        #coordinate list of intersection points
        if IntersectionsMP.geom_type == 'MultiPoint':
            InterCoords = [(p.x, p.y) for p in IntersectionsMP] #works for multiPoint
        elif IntersectionsMP.geom_type == 'Point':
            InterCoords = list(NLines.unary_union.intersection(line).coords)#works for point
        #resolve every intersection
        for point in InterCoords: #check if nodes already exist in networkx graph
            if(point not in GCoordList): #if node doesn't exist split line, find neighbor nodes, remove/add edges
                #find linestrings 
                nodeNum = nodeNum +1
                GS.add_node(nodeNum, food = 0, coord=point) #add node to networkx
                for zine in IntersectLines:
                    if(zine.intersects(Point(point))):#lines to be split
                        nc1 = zine.coords[0] #endpoint of line/networkx node
                        n1 = invertNodesDict[nc1]#networkx node labels found
                        nc2 = zine.coords[1]
                        n2 = invertNodesDict[nc2]
                        Eattr = GS.edges[n1,n2] #get existing edge attributes
                        GS.add_edge(n1,nodeNum, Eattr)#create new edges
                        GS.edges[n1,nodeNum]['length'] = edgeLength(nc1, point)
                        GS.add_edge(n2,nodeNum, Eattr)
                        GS.edges[n2,nodeNum]['length'] = edgeLength(nc2, point)
                        GS.remove_edge(n1,n2)#remove existing edge
                        #don't really need to split in shapely so don't

    #            newLines = shapely.ops.split(NLines, line)

# %%
#zipNodes and edges
#takes in Graph GS
#if two nodes are very close and connected by a short edge
#^(the 2 nodes connected to a very short edge)
#then place node between two existing nodes connect edges to new node, remove old nodes
#if this causes mulitedge then zip multi-edges attributes togethor

# %%
# G is graph with node attributes 'coord' and edge attribute 'weight'
#FoodMap is a Shapely multiPolygon containg polygons with food
def plotSim( G, FoodMap):
    for poly in FoodMap:
        plt.plot(*poly.exterior.xy, color = 'red')
    nx.draw(Gsim, pos =Gsim.nodes(data = 'coord'), width=standardWidth(Gsim) , node_size = 2)
    plt.show()

# %%
###########TESTER#####
Gsim = nx.Graph()
HarvestRate = 7
nx.set_node_attributes(Gsim, 0 , 'food')
nx.set_node_attributes(GC, (0,0), 'coord')

nx.set_edge_attributes(GC, 0, 'flow')
nx.set_edge_attributes(GC, 0, 'resistance')
nx.set_edge_attributes(GC, 0, 'weight')
#nx.set_edge_attributes(GC, 0, 'plasticity')
nx.set_edge_attributes(GC, 0, 'length')#technically dont need can be sourced from node data
nx.set_edge_attributes(GC, 0, '')


Gsim.add_node(0, food = HarvestRate, coord=(0,0))
Gsim.add_node(1, food = HarvestRate, coord=(5.2,5.2))



# #initialize graph
Gsim.nodes[0]['food'] = HarvestRate
while(Gsim.nodes[0]['food'] > 0):
    #coordinates, weight, length, food left
    NewGrowth = hyphalGrowth(Gsim.nodes[0]['coord'], Gsim.nodes[0]['food'] )
    nodeNum = Gsim.number_of_nodes()
    Gsim.add_node(nodeNum, food = 0, coord= NewGrowth[0])
    Gsim.add_edge(0,nodeNum, weight = NewGrowth[1], length = NewGrowth[2])
    Gsim.nodes[0]['food'] = NewGrowth[3]
# #CONTINUATION PHASE

# Harvest Food
# #At beginning of each phase distribute food to nodes and then to edges if exist also rand new edge
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-76b15abdfe41> in <module>
#       3 HarvestRate = 7
#       4 nx.set_node_attributes(Gsim, 0 , 'food')
# ----> 5 nx.set_node_attributes(GC, (0,0), 'coord')
#       6
#       7 nx.set_edge_attributes(GC, 0, 'flow')
#
# NameError: name 'GC' is not defined

# %%
###############USEFULL################
#adds convolution for testing
Gsim.nodes[3]['food'] = HarvestRate
while(Gsim.nodes[3]['food'] > 0):
    #coordinates, weight, length, food left
    NewGrowth = hyphalGrowth(Gsim.nodes[3]['coord'], Gsim.nodes[3]['food'] )
    nodeNum = Gsim.number_of_nodes()
    Gsim.add_node(nodeNum, food = 0, coord= NewGrowth[0])
    Gsim.add_edge(3,nodeNum, weight = NewGrowth[1], length = NewGrowth[2])
    Gsim.nodes[3]['food'] = NewGrowth[3]
Gsim.nodes[2]['food'] = HarvestRate
while(Gsim.nodes[2]['food'] > 0):    
    #coordinates, weight, length, food left
    NewGrowth = hyphalGrowth(Gsim.nodes[2]['coord'], Gsim.nodes[2]['food'] )
    nodeNum = Gsim.number_of_nodes()
    Gsim.add_node(nodeNum, food = 0, coord= NewGrowth[0])
    Gsim.add_edge(2,nodeNum, weight = NewGrowth[1], length = NewGrowth[2])
    Gsim.nodes[2]['food'] = NewGrowth[3]

# %%
plotSim(Gsim, foodMap)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-026c3ddb6f3f> in <module>
# ----> 1 plotSim(Gsim, foodMap)
#
# NameError: name 'plotSim' is not defined

# %%
#############THIS IS THE MAIN WORKING SIMULATION#####(1/2)

# #initialize graph
Gsim = nx.Graph()
HarvestRate = 7 #ADJUST VALUE
nx.set_node_attributes(Gsim, 0 , 'food')
nx.set_node_attributes(Gsim, (0,0), 'coord')

nx.set_edge_attributes(Gsim, 0, 'flow')
nx.set_edge_attributes(Gsim, 0, 'resistance')
nx.set_edge_attributes(Gsim, 0, 'weight')
#nx.set_edge_attributes(GC, 0, 'plasticity')
nx.set_edge_attributes(Gsim, 0, 'length')#technically dont need can be sourced from node data
nx.set_edge_attributes(Gsim, 0, '')

#set food sources map
f1 = Polygon([(0,0),(0,0.3),(0.3,0.3),(0.3,0)])
f2 = Polygon([(5,5),(5,6),(6,5)])
f3 = Polygon([(0,5),(1,5),(0,6)])
foodMap = MultiPolygon([f1,f2,f3])
#intial innoculation points
Gsim.add_node(0, food = HarvestRate, coord=(0.2,0.2))
Gsim.add_node(1, food = HarvestRate, coord=(5.2,5.2))
nodeNum = 1
#Gsim.add_node(2, food = HarvestRate, coord=(0.5,5.3))
#nodeNum = 2


#node iteration
tempGN = list(Gsim.nodes(data =True))#holds static for loop
for Nodes in tempGN:
    if( hasFood(Nodes[1]['coord'], foodMap)):
        Nodes[1]['food'] = HarvestRate
        #distribute food to immediately connected edges or add new edge
        #hyphal growth or distribute to edges??
        neighborWsum = sum([x[2] for x in list(Gsim.edges(Nodes[0], data = 'weight'))])
        hyphalFood = ranged_normal(0.2, 0.3, 0, 1)[0] * Nodes[1]['food']
        contFood = Nodes[1]['food'] - hyphalFood
        
       # for kEdge in Gsim.edges(Nodes[0]):
        #    contFood = porpEdgeGrowth(Gsim, kEdge,  contFood, neighborWsum)
        
        while(Nodes[1]['food'] > 0):#distribute all harvested food
            #coordinates, weight, length, food left
            NewGrowth = hyphalGrowth(Nodes[1]['coord'], Nodes[1]['food'] )
            nodeNum = nodeNum +1
            Gsim.add_node(nodeNum, food = 0, coord= NewGrowth[0])
            Gsim.add_edge(Nodes[0],nodeNum, weight = NewGrowth[1], length = NewGrowth[2], Rigidness = 0, PhaseRigid = 0, PhaseAbsFlow = 0, PrevPhFlow = NewGrowth[1]*NewGrowth[2])
            Nodes[1]['food'] = NewGrowth[3]

tempGE = list(Gsim.edges(data =True))
plotSim(Gsim, foodMap)

# %%
HarvestRate = 0.5

# %%
#############THIS IS THE MAIN WORKING SIMULATION#####(2/2)
####Executes single phase iteration for nodes and edges
##Repeat execution to run more phases

# iterate through nodes
tempGN = list(Gsim.nodes(data =True))#holds static for loop
for Nodes in tempGN:
    if( hasFood(Nodes[1]['coord'], foodMap)):#nodes only distribute resources if they are located over food sources
        Nodes[1]['food'] = HarvestRate
        #distribute food to immediately connected edges or add new edge
        #hyphal growth or distribute to edges??
        neighborWsum = sum([x[2] for x in list(Gsim.edges(Nodes[0], data = 'weight'))])
        hyphalFood = ranged_normal(0.2, 0.1, 0, 1)[0] * Nodes[1]['food']#ADJUST VALUE controls resource distribution to new edges or existing edges
        contFood = Nodes[1]['food'] - hyphalFood
        for kEdge in Gsim.edges(Nodes[0]):
            contFood = porpEdgeGrowth(Gsim, kEdge,  contFood, neighborWsum)
        
        while(Nodes[1]['food'] > 0.1):#ADJUST VALUE 
            #coordinates, weight, length, food left
            NewGrowth = hyphalGrowth(Nodes[1]['coord'], Nodes[1]['food'] )
            nodeNum = nodeNum+1
            Gsim.add_node(nodeNum, food = 0, coord= NewGrowth[0])
            Gsim.add_edge(Nodes[0],nodeNum, weight = NewGrowth[1], length = NewGrowth[2], Rigidness = 0, PhaseRigid = 0, PhaseAbsFlow = 0, PrevPhFlow = NewGrowth[1]*NewGrowth[2])
            Nodes[1]['food'] = NewGrowth[3]
            
            
#iterate through edges
tempGE = list(Gsim.edges())
for Edgek in tempGE:
    #total resources capable of distributing
    transfer = ResourceTransferAmount(Gsim, Edgek)
    #TODO pressure causes hyphal growth vs. edge growth
    hyphalFood = ranged_normal(0.2, 0.05, 0, 0.4)[0] * transfer #add paramaters to distribution to affect hyphal growth/decay
    contFood = transfer - hyphalFood
    AllEdges = list(Gsim.edges(Edgek[0])) #TODO need to make asyncronous 
    AllEdges += list(Gsim.edges(Edgek[1]))
    neighborWsum = sum([Gsim.edges[x]['weight'] for x in AllEdges] )#TODO make asychronous
    for kEdge in AllEdges :
            contFood = porpEdgeGrowth(Gsim, kEdge,  contFood, neighborWsum)
    i = 0
    while(hyphalFood > 0.2):####VALUE TO ADJUST
        if(i == 0):#switch between which side the resources are being transfered to
            i = 1
        else:
            i = 0
        #TODO hyphal growth from edge midpoints instead
        
        #coordinates, weight, length, food left
        NewGrowth = hyphalGrowth(Gsim.nodes[Edgek[i]]['coord'], hyphalFood )
        nodeNum = nodeNum +1 
        Gsim.add_node(nodeNum, food = 0, coord= NewGrowth[0])
        Gsim.add_edge(Edgek[i],nodeNum, weight = NewGrowth[1], length = NewGrowth[2], Rigidness = 0, PhaseRigid = 0, PhaseAbsFlow = 0, PrevPhFlow = NewGrowth[1]*NewGrowth[2])
        hyphalFood = NewGrowth[3]

#remove small weighted edges
for Edgek in  list(Gsim.edges()):
    if(Gsim.edges[Edgek]['weight'] < 0.1):####VALUE TO ADJUST BETWEEN ITERATIONS
        
        Gsim.remove_edge(Edgek[0], Edgek[1])
        
Gsim.remove_nodes_from(list(nx.isolates(Gsim)))
ResolveIntersections(Gsim, nodeNum)#takes a long time to run but is neccessarry


plotSim(Gsim, foodMap)

# %%
#############THIS IS a test WORKING SIMULATION#####(2/2)
####Executes single phase iteration for nodes and edges
##Repeat execution to run more phases

# iterate through nodes
tempGN = list(Gsim.nodes(data =True))#holds static for loop
for Nodes in tempGN:
    if( hasFood(Nodes[1]['coord'], foodMap)):#nodes only distribute resources if they are located over food sources
        Nodes[1]['food'] = HarvestRate
        #distribute food to immediately connected edges or add new edge
        #hyphal growth or distribute to edges??
        neighborWsum = sum([x[2] for x in list(Gsim.edges(Nodes[0], data = 'weight'))])
        hyphalFood = ranged_normal(0.2, 0.1, 0, 1)[0] * Nodes[1]['food']#ADJUST VALUE controls resource distribution to new edges or existing edges
        contFood = Nodes[1]['food'] - hyphalFood
        for kEdge in Gsim.edges(Nodes[0]):
            contFood = porpEdgeGrowth(Gsim, kEdge,  contFood, neighborWsum)
        
        while(Nodes[1]['food'] > 0.1):#ADJUST VALUE 
            #coordinates, weight, length, food left
            NewGrowth = hyphalGrowth(Nodes[1]['coord'], Nodes[1]['food'] )
            nodeNum = nodeNum+1
            Gsim.add_node(nodeNum, food = 0, coord= NewGrowth[0])
            Gsim.add_edge(Nodes[0],nodeNum, weight = NewGrowth[1], length = NewGrowth[2], Rigidness = 0, PhaseRigid = 0, PhaseAbsFlow = 0, PrevPhFlow = NewGrowth[1]*NewGrowth[2])
            Nodes[1]['food'] = NewGrowth[3]
            
            
#iterate through edges
tempGE = list(Gsim.edges())
for Edgek in tempGE:
    #total resources capable of distributing
    transfer = ResourceTransferAmount(Gsim, Edgek)
    #TODO pressure causes hyphal growth vs. edge growth
    hyphalFood = ranged_normal(0.2, 0.05, 0, 0.4)[0] * transfer #add paramaters to distribution to affect hyphal growth/decay
    contFood = transfer - hyphalFood
    AllEdges = list(Gsim.edges(Edgek[0])) #TODO need to make asyncronous 
    AllEdges += list(Gsim.edges(Edgek[1]))
    neighborWsum = sum([Gsim.edges[x]['weight'] for x in AllEdges] )#TODO make asychronous
    for kEdge in AllEdges :
            contFood = porpEdgeGrowth(Gsim, kEdge,  contFood, neighborWsum)
    i = 0
    while(hyphalFood > 0.7):####VALUE TO ADJUST
        if(i == 0):#switch between which side the resources are being transfered to
            i = 1
        else:
            i = 0
        #TODO hyphal growth from edge midpoints instead
        
        #coordinates, weight, length, food left
        NewGrowth = hyphalGrowth(Gsim.nodes[Edgek[i]]['coord'], hyphalFood )
        nodeNum = nodeNum +1 
        Gsim.add_node(nodeNum, food = 0, coord= NewGrowth[0])
        Gsim.add_edge(Edgek[i],nodeNum, weight = NewGrowth[1], length = NewGrowth[2], Rigidness = 0, PhaseRigid = 0, PhaseAbsFlow = 0, PrevPhFlow = NewGrowth[1]*NewGrowth[2])
        hyphalFood = NewGrowth[3]

#remove small weighted edges
for Edgek in  list(Gsim.edges()):
    if(Gsim.edges[Edgek]['weight'] < 0.01):####VALUE TO ADJUST BETWEEN ITERATIONS
        #TODO redistribute instead of delete
        Gsim.remove_edge(Edgek[0], Edgek[1])
        
Gsim.remove_nodes_from(list(nx.isolates(Gsim)))
#ResolveIntersections(Gsim, nodeNum)#takes a long time to run but is neccessarry


plotSim(Gsim, foodMap)
# Out:
# node:  (0, {'food': 7, 'coord': (0.2, 0.2)}) , contFOOD: 5.492745258374322
# node:  (1, {'food': 7, 'coord': (5.2, 5.2)}) , contFOOD: 5.3794757064713625
# node:  (131, {'food': 7, 'coord': (5.703965771131866, 5.047961626775614)}) , contFOOD: 6.774804030210409
# node:  (280, {'food': 7, 'coord': (5.818236381001345, 5.046112340756245)}) , contFOOD: 5.841476037300542
# node:  (381, {'food': 7, 'coord': (5.610506279431364, 5.295671585355096)}) , contFOOD: 5.746299158639595
# node:  (477, {'food': 7, 'coord': (5.553415106445685, 5.405246099471934)}) , contFOOD: 5.587674578891795
# node:  (521, {'food': 7, 'coord': (5.379634945028201, 5.513765424352657)}) , contFOOD: 6.772519881420463
# node:  (568, {'food': 7, 'coord': (5.092454751042969, 5.646890135895827)}) , contFOOD: 5.599113858311615
# node:  (608, {'food': 7, 'coord': (5.336282377535012, 5.657872348083636)}) , contFOOD: 5.481415134178832
# node:  (4467, {'food': 7, 'coord': (5.547460731856493, 5.11073701310294)}) , contFOOD: 6.4161265256358995
# node:  (4468, {'food': 7, 'coord': (5.553362202352088, 5.1155721152702185)}) , contFOOD: 6.607771834181328
# node:  (4472, {'food': 7, 'coord': (5.5993162316806595, 5.153222464783542)}) , contFOOD: 5.176307197215269
# node:  (4475, {'food': 7, 'coord': (5.414721657950407, 5.204635711829843)}) , contFOOD: 4.448199753261868
# node:  (4484, {'food': 7, 'coord': (5.745591923536834, 5.22122053146693)}) , contFOOD: 5.983591486512357
# node:  (4497, {'food': 7, 'coord': (5.105806586601913, 5.284969867050111)}) , contFOOD: 6.193494244091239
# node:  (4498, {'food': 7, 'coord': (5.109509832910992, 5.273489352052)}) , contFOOD: 5.270033349533881
# node:  (4499, {'food': 7, 'coord': (5.112717978494804, 5.263543709656899)}) , contFOOD: 5.259393922577347
# node:  (4505, {'food': 7, 'coord': (5.138034222030337, 5.185060268549312)}) , contFOOD: 6.180499326150773
# node:  (4511, {'food': 7, 'coord': (5.151035317765732, 5.144755286886023)}) , contFOOD: 5.517580803232755
# node:  (4516, {'food': 7, 'coord': (5.171689837974136, 5.080723756374536)}) , contFOOD: 4.817798506019431
# node:  (4547, {'food': 7, 'coord': (5.076428039980546, 5.248392795774363)}) , contFOOD: 3.7703280817766527
# node:  (4548, {'food': 7, 'coord': (5.094043002890693, 5.273248233017321)}) , contFOOD: 6.709432073887037
# node:  (4549, {'food': 7, 'coord': (5.095862192767854, 5.275815184764846)}) , contFOOD: 6.762533006227539
# node:  (4550, {'food': 7, 'coord': (5.0998015113807185, 5.281373725368169)}) , contFOOD: 5.518577398876003
# node:  (4551, {'food': 7, 'coord': (5.103698063513059, 5.286871920708308)}) , contFOOD: 6.094704355673542
# node:  (4558, {'food': 7, 'coord': (5.97591578646852, 5.019137777160232)}) , contFOOD: 5.9114042714039075

# %%
for Edgek in  list(Gsim.edges()):
    if(Gsim.edges[Edgek]['weight'] < 1):
        Gsim.remove_edge(Edgek[0], Edgek[1])
Gsim.remove_nodes_from(list(nx.isolates(Gsim)))
#ResolveIntersections(Gsim, nodeNum)

# %%
plotSim(Gsim, foodMap)

# %%
import copy as copy

# %%
#Gsim1 = copy.deepcopy(Gsim)
plotSim(Gsim1, foodMap)

# %%
#Gsim2 = Gsim.copy()
plotSim(Gsim2, foodMap)

# %%
Gsim.edges(data=True)
# Out:
# EdgeDataView([(0, 3, {'weight': 3.8859079785919843, 'length': 2.922665094655887, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 3.520759761662079}), (0, 4, {'weight': 2.4248230902211017, 'length': 2.465186174483463, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 1.1074374776035274}), (0, 5, {'weight': 7.203832349153717, 'length': 0.634488281990643, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.9941494207457962}), (0, 6, {'weight': 1.0062285285624157, 'length': 2.285120856506841, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.7322467796484724}), (0, 7, {'weight': 0.7052088014171082, 'length': 1.5149388329866817, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.19064326825399408}), (0, 8, {'weight': 0.5317930415694788, 'length': 1.627063486398095, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.45476329208613075}), (0, 9, {'weight': 0.2963479048708017, 'length': 1.5255950721535028, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 5.551115123125782e-17}), (0, 10, {'weight': 0.1676650998526718, 'length': 2.1310241687575897, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 6.162975822039155e-33}), (0, 23, {'weight': 0.2176302192875652, 'length': 2.3798525397013788, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 3.3641137409161916}), (0, 24, {'weight': 0.06788296393034703, 'length': 2.595569185570193, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 1.76175234819355}), (0, 25, {'weight': 0.06069122097744922, 'length': 2.081782694003562, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.6364508944436157}), (0, 26, {'weight': 0.054962786013286455, 'length': 2.305097412514683, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.6756532436737185}), (0, 27, {'weight': 0.0018494291699809925, 'length': 1.07765933399111, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.5154289625233336}), (0, 39, {'weight': 0.007640124036557235, 'length': 1.8933258572024343, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.5568631978394074}), (0, 41, {'weight': 0.0011302825546445124, 'length': 1.1509058634028346, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.15896108526443053}), (0, 43, {'weight': 0.0016154273679868248, 'length': 2.138898415189403, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.35276339321876904}), (0, 49, {'weight': 0.0028468018053928496, 'length': 2.4162707449888825, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.5298217234966189}), (0, 51, {'weight': 0.0008318949758813644, 'length': 2.0609856604488024, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.24232613597020422}), (0, 80, {'weight': 0.06814495282824184, 'length': 3.115727872295087, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 3.505538512707543}), (0, 81, {'weight': 0.061974786634063486, 'length': 1.7455356932181931, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 1.930662305959545}), (0, 82, {'weight': 0.002226507489986721, 'length': 1.8689774710161973, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.37242791007329784}), (0, 83, {'weight': 0.025717355057600557, 'length': 1.652711357342173, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 1.1506197790222072}), (0, 149, {'weight': 0.2393528424423454, 'length': 1.3462161997591284, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.3222206739542796}), (0, 152, {'weight': 0.5249271042677223, 'length': 1.4578974118939672, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.765289866744907}), (0, 155, {'weight': 0.19638366474776559, 'length': 1.3139180777931772, 'Rigidness': 0, 'PhaseRigid': 0, 'PhaseAbsFlow': 0, 'PrevPhFlow': 0.2580320472953639}), (0, 158, {'weight': 0.17925817411936615, 'le ...

# %%
plotSim(Gsim, foodMap)

# %%
Gsim.remove_nodes_from(list(nx.isolates(Gsim)))
plotSim(Gsim, foodMap)

# %%
Gsim.edges(3)
# Out:
# EdgeDataView([(3, 0)])

# %%
Edge = (0,2)
Available = Gsim.edges[Edge]['weight'] * Gsim.edges[Edge]['length']
SumNeighborWeights = sum([x[2] for x in list(Gsim.edges(Edge[0], data = 'weight'))]) + sum([x[2] for x in list(Gsim.edges(Edge[1], data = 'weight'))]) + Gsim.edges[Edge]['weight'] 
transfer =(Available*(Gsim.edges[Edge]['weight']/SumNeighborWeights))
transfer *= 0.2
(transfer/Gsim.edges[Edge]['length'])
# Out:
# 0.14438113910445496

# %%
###############USEFULL################
#adds convolution for testing
Gsim.nodes[3]['food'] = HarvestRate
while(Gsim.nodes[3]['food'] > 0):
    #coordinates, weight, length, food left
    NewGrowth = hyphalGrowth(Gsim.nodes[3]['coord'], Gsim.nodes[3]['food'] )
    nodeNum = Gsim.number_of_nodes()
    Gsim.add_node(nodeNum, food = 0, coord= NewGrowth[0])
    Gsim.add_edge(3,nodeNum, weight = NewGrowth[1], length = NewGrowth[2])
    Gsim.nodes[3]['food'] = NewGrowth[3]
Gsim.nodes[2]['food'] = HarvestRate
while(Gsim.nodes[2]['food'] > 0):
    #coordinates, weight, length, food left
    NewGrowth = hyphalGrowth(Gsim.nodes[2]['coord'], Gsim.nodes[2]['food'] )
    nodeNum = Gsim.number_of_nodes()
    Gsim.add_node(nodeNum, food = 0, coord= NewGrowth[0])
    Gsim.add_edge(2,nodeNum, weight = NewGrowth[1], length = NewGrowth[2])
    Gsim.nodes[2]['food'] = NewGrowth[3]

# %%
plotSim(Gsim, foodMap)

# %%
ResolveIntersections(Gsim)
plotSim(Gsim, foodMap)

# %%
list(NLines.unary_union.intersection(line).coords)

# %%
MultiPoint([NLines.unary_union.intersection(line)])

# %%
NLines2 = gpd.GeoSeries(NLines)

Intersection = gpd.GeoSeries([NLines2.unary_union.intersection(line)])
Intersection

# %%
NLines2.unary_union.intersection(line)[0].y

# %%
list(Gsim.edges())[0]

# %%
nx.get_edge_attributes(Gsim, 'weight')
# Out:
# {(0, 2): array([0.34085259]),
#  (0, 3): array([0.00127696]),
#  (0, 4): array([0.00909292]),
#  (0, 5): array([0.01666037]),
#  (0, 6): array([0.00844493]),
#  (0, 7): array([0.00257425]),
#  (0, 13): array([0.25410235]),
#  (0, 14): array([0.02028341]),
#  (0, 15): array([0.00392616]),
#  (0, 16): array([0.00303157]),
#  (0, 17): array([0.03121228]),
#  (0, 18): array([0.00816653]),
#  (1, 8): array([0.43788583]),
#  (1, 9): array([0.01708866]),
#  (1, 10): array([0.01059409]),
#  (1, 11): array([0.00192936]),
#  (1, 12): array([0.00170912]),
#  (1, 19): array([0.13109282]),
#  (1, 20): array([0.02591674]),
#  (1, 21): array([0.03244891]),
#  (1, 22): array([0.00584687]),
#  (1, 23): array([0.00271569]),
#  (2, 24): 0.029063096846553078,
#  (3, 25): 0.0003310646800868648,
#  (4, 26): 0.0017772248890427537,
#  (5, 27): 0.0021177996054011,
#  (6, 28): 0.0012299060515293951,
#  (7, 29): 0.0005417942793915811,
#  (8, 37): 0.014640108207888447,
#  (9, 38): 0.004042549285501444,
#  (10, 39): 0.0021136626082957936,
#  (11, 40): 0.0003894625485500111,
#  (12, 41): 0.0003353430021642729,
#  (13, 30): 0.016612460981073846,
#  (14, 32): 0.004439047574866374,
#  (15, 33): 0.0007296110263725348,
#  (16, 34): 0.0004719577653409355,
#  (17, 35): 0.006413332118521614,
#  (18, 36): 0.001022233295633095,
#  (19, 42): 0.0191029571903898,
#  (20, 43): 0.009122898262558531,
#  (21, 44): 0.005587279747477439,
#  (22, 45): 0.0007301894937639731,
#  (23, 47): 0.0007697073441853324}

# %%
ResolveIntersections(GC)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-280-ca64ef0e6c83> in <module>
# ----> 1 ResolveIntersections(GC)
#
# <ipython-input-268-526fd3207b3c> in ResolveIntersections(GS)
#      24             InterCoords = list(NLines.unary_union.intersection(line).coords)#works for point
#      25         #resolve every intersection
# ---> 26         for point in InterCoords: #check if nodes already exist in networkx graph
#      27             if(point not in GCoordList): #if node doesn't exist split line, find neighbor nodes, remove/add edges
#      28                 #find linestrings
#
# UnboundLocalError: local variable 'InterCoords' referenced before assignment
